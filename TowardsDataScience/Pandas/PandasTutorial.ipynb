# %% [markdown]
# # Olympics data

# %% [markdown]
# The dataset contains 2 sheet “Bios” and “Results”
#
# [Link to the original source](https://medium.com/@soulawalid/pandas-tutorial-ii-2024-update-1a5d6ca4ddb3)

# %%
import pandas as pd

bios = pd.read_excel(r'C:\\Users\\ce_ra\\Documents\\CIMAT\\Python\\Experimentos\\TowardsDataScience\\Pandas\\olympics-data.xlsx')
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
results = pd.read_excel(r'C:\\Users\\ce_ra\\Documents\\CIMAT\\Python\\Experimentos\\TowardsDataScience\\Pandas\\olympics-data.xlsx', sheet_name = 'results')
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# ### Saving the file to another format

# %%
# Save to another format
results.to_parquet(r'C:\\Users\\ce_ra\\Documents\\CIMAT\\Python\\Experimentos\\TowardsDataScience\\Pandas\\olympics-data.parquet')

# Read it
results2 = pd.read_parquet(r'C:\\Users\\ce_ra\\Documents\\CIMAT\\Python\\Experimentos\\TowardsDataScience\\Pandas\\olympics-data.parquet')
results2
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# ### Access a random sample of the data

# %%
results2.sample(10)
# results2.sample((10),random_state =1)
# Out:
#           year    type                        discipline  \
# 124637  1964.0  Summer                         Wrestling
# 275717  2018.0  Winter                          Biathlon
# 277000  2016.0  Summer              Rugby Sevens (Rugby)
# 189960  2008.0  Summer                          Handball
# 48168   1972.0  Summer               Football (Football)
# 117234  2000.0  Summer           Volleyball (Volleyball)
# 65779   1936.0  Summer  Artistic Gymnastics (Gymnastics)
# 218289  2006.0  Winter     Cross Country Skiing (Skiing)
# 38391   1912.0  Summer                           Fencing
# 242539  2008.0  Summer           Volleyball (Volleyball)
#
#                                            event  \
# 124637  Welterweight, Greco-Roman, Men (Olympic)
# 275717              20 kilometres, Men (Olympic)
# 277000             Rugby Sevens, Women (Olympic)
# 189960                 Handball, Women (Olympic)
# 48168                    Football, Men (Olympic)
# ...

# %% [markdown]
# ### Access specific part of the data

# %%
results2.loc[0]
# Out:
# year                          1912.0
# type                          Summer
# discipline                    Tennis
# event         Singles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                            None
# place                           17.0
# tied                            True
# medal                           None
# Name: 0, dtype: object

# %%
# Slice
results2.loc[0:3]
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None

# %%
# Slide with rows and columns with loc
results2.loc[0:2, ['type','team']]
# Out:
#      type            team
# 0  Summer            None
# 1  Summer  Jean Montariol
# 2  Summer            None

# %%
# All rows and specific columns with loc
results2.loc[:, ['type','team']]
# Out:
#           type             team
# 0       Summer             None
# 1       Summer   Jean Montariol
# 2       Summer             None
# 3       Summer  Jeanne Vaussard
# 4       Summer  Jacques Brugnon
# ...        ...              ...
# 308403  Winter             None
# 308404  Winter             None
# 308405  Winter           Sweden
# 308406  Winter             None
# 308407  Winter             None
#
# [308408 rows x 2 columns]

# %% [markdown]
# ### Changing the index of the DataFrame

# %%
# Changing the index
results2.index = results2['type']

# %% [markdown]
# ### Restore the index

# %%
results2 = pd.read_parquet(r'C:\\Users\\ce_ra\\Documents\\CIMAT\\Python\\Experimentos\\TowardsDataScience\\Pandas\\olympics-data.parquet')
# Changing the index
results2.set_index('type', inplace=True)
# Restore the index
results_restored = results2.reset_index()
results_restored
# Out:
#           type    year              discipline                          event  \
# 0       Summer  1912.0                  Tennis         Singles, Men (Olympic)
# 1       Summer  1912.0                  Tennis         Doubles, Men (Olympic)
# 2       Summer  1920.0                  Tennis         Singles, Men (Olympic)
# 3       Summer  1920.0                  Tennis       Doubles, Mixed (Olympic)
# 4       Summer  1920.0                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  Winter  2022.0                    Luge         Singles, Men (Olympic)
# 308404  Winter  2022.0  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  Winter  2022.0  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  Winter  2022.0  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  Winter  2022.0                    None        Slalom, Women (Olympic)
#
# ...

# %% [markdown]
# You can’t now use **loc** to grab specifics values ,you will get an error since it’s a qualitative value, you can use the following

# %%
# Using loc from the new index
results2.loc['Summer']
# Out:
#           year                      discipline                       event  \
# type
# Summer  1912.0                          Tennis      Singles, Men (Olympic)
# Summer  1912.0                          Tennis      Doubles, Men (Olympic)
# Summer  1920.0                          Tennis      Singles, Men (Olympic)
# Summer  1920.0                          Tennis    Doubles, Mixed (Olympic)
# Summer  1920.0                          Tennis      Doubles, Men (Olympic)
# ...        ...                             ...                         ...
# Summer  1996.0           Water Polo (Aquatics)   Water Polo, Men (Olympic)
# Summer  1920.0                          Rowing  Coxed Fours, Men (Olympic)
# Summer  2018.0  Roller Skating (Roller Sports)        Combined, Boys (YOG)
# Summer  2018.0                       Triathlon         Sprint, Girls (YOG)
# Summer  2018.0                       Triathlon    Relay, Mixed Youth (YOG)
#
# ...

# %% [markdown]
# You can also have **Multiple filters**

# %%
# Multple filters
results2.loc['Summer', 'medal']
# Out:
# type
# Summer      None
# Summer      None
# Summer      None
# Summer      None
# Summer      None
#            ...
# Summer      None
# Summer      None
# Summer    Bronze
# Summer    Bronze
# Summer      Gold
# Name: medal, Length: 241298, dtype: object

# %% [markdown]
# ### **at** and **iat** :
#
# There is also other method to get access to specific values using at and iat for specific items
#
# * For example I want to look at the 0 index and have the discipline, I can do the following

# %%
results2.at[0, "discipline"] #'Tennis'
